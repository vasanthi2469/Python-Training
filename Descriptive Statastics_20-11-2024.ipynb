# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi2469/Python-Training/blob/main/DAY-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/daniellopez01/credit-risk")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vanisanthoshi
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/daniellopez01/credit-risk
# ...
# 100%|██████████| 13.4k/13.4k [00:00<00:00, 6.32MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/credit-risk/credit.csv')

# %%
data.head()
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3           < 0 DM                    42           good  furniture/appliances
# 4           < 0 DM                    24           poor                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951        < 100 DM         1 - 4 years                  2
# 2    2096        < 100 DM         4 - 7 years                  2
# 3    7882        < 100 DM         4 - 7 years                  2
# 4    4870        < 100 DM         1 - 4 years                  3
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew
import statistics

# Assuming the data is already loaded in a DataFrame named 'df'

# Statistical Measures for Numerical Data
numerical_columns = ["months_loan_duration", "amount", "percent_of_income", "years_at_residence", "age", "existing_loans_count", "dependents"]
print("Numerical Data Summary:")

for col in numerical_columns:
    print(f"\n{col}:")
    mean = statistics.mean(df[col])
    median = statistics.median(df[col])
    data_range = max(df[col]) - min(df[col])
    data_skewness = skew(df[col])
    variance = np.var(df[col], ddof=1)  # Using sample variance (ddof=1)
    std_deviation = np.std(df[col], ddof=1)  # Sample standard deviation

    print(f"Mean: {mean}")
    print(f"Median: {median}")
    print(f"Range: {data_range}")
    print(f"Skewness: {data_skewness}")
    print(f"Variance: {variance}")
    print(f"Standard Deviation: {std_deviation}")

# Outlier Detection (using Z-score method for numerical columns)
def detect_outliers(data):
    z_scores = [(x - np.mean(data)) / np.std(data) for x in data]
    outliers = [x for x, z in zip(data, z_scores) if abs(z) > 3]
    return outliers

for col in numerical_columns:
    outliers = detect_outliers(df[col])
    print(f"Outliers in {col}: {outliers}")

# Categorical Data Analysis (Frequency & Mode)
categorical_columns = ["checking_balance", "credit_history", "purpose", "savings_balance", "employment_duration", "other_credit", "housing", "job", "phone", "default"]
print("\nCategorical Data Summary:")

for col in categorical_columns:
    print(f"\n{col}:")
    mode = statistics.mode(df[col])
    value_counts = df[col].value_counts()

    print(f"Mode: {mode}")
    print(f"Value Counts:\n{value_counts}")
# Out:
# Numerical Data Summary:
#
# months_loan_duration:
# Mean: 26.4
# Median: 24
# Range: 42
# Skewness: 0.10880269824164941
# Variance: 334.8
# Standard Deviation: 18.297540818372287
#
# amount:
# Mean: 4393.6
# Median: 4870
# Range: 6713
# Skewness: 0.00899069949878133
# Variance: 7624599.300000001
# Standard Deviation: 2761.267697996701
#
# percent_of_income:
# Mean: 2.6
# Median: 2
# Range: 2
# Skewness: 0.8437499999999996
# Variance: 0.8
# Standard Deviation: 0.8944271909999159
#
# years_at_residence:
# Mean: 3.4
# Median: 4
# Range: 2
# Skewness: -0.8437499999999996
# Variance: 0.8
# Standard Deviation: 0.8944271909999159
#
# age:
# Mean: 47.2
# Median: 49
# Range: 45
# Skewness: -0.5151734562458539
# Variance: 267.2
# Standard Deviation: 16.34625339336204
#
# existing_loans_count:
# Mean: 1.4
# Median: 1
# Range: 1
# Skewness: 0.4082482904638635
# Variance: 0.3
# Standard Deviation: 0.5477225575051661
#
# dependents:
# Mean: 1.6
# Median: 2
# Range: 1
# ...
