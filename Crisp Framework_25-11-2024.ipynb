# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi2469/Python-Training/blob/main/DAY-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import opendatasets as od

od.download("https://www.kaggle.com/datasets/brendan45774/test-file")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vanisanthoshi
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/brendan45774/test-file
# ...
# 100%|██████████| 11.2k/11.2k [00:00<00:00, 4.92MB/s]

# %%
# !pip install opendatasets

# %%
import pandas as pd
import numpy as np
Titanic = pd.read_csv('/content/test-file/tested.csv')

# %%
Titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
Titanic.Fare
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
Titanic.count()
# Out:
# PassengerId    418
# Survived       418
# Pclass         418
# Name           418
# Sex            418
# Age            332
# SibSp          418
# Parch          418
# Ticket         418
# Fare           417
# Cabin           91
# Embarked       418
# dtype: int64

# %%
Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
Titanic.shape
# Out:
# (418, 12)

# %%
Titanic.drop('PassengerId', axis=1)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
Titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
Titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
Titanic.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic.fillna(value=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
Titanic.groupby("Name")

# %%
Titanic.pivot_table(values="Age", index="Name", columns="Pclass")
# Out:
# Pclass                                          1     2     3
# Name
# Abbott, Master. Eugene Joseph                 NaN   NaN  13.0
# Abelseth, Miss. Karen Marie                   NaN   NaN  16.0
# Abelseth, Mr. Olaus Jorgensen                 NaN   NaN  25.0
# Abrahamsson, Mr. Abraham August Johannes      NaN   NaN  20.0
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)     NaN   NaN  18.0
# ...                                            ..   ...   ...
# Zakarian, Mr. Ortin                           NaN   NaN  27.0
# de Brito, Mr. Jose Joaquim                    NaN  32.0   NaN
# de Messemaeker, Mr. Guillaume Joseph          NaN   NaN  36.5
# del Carlo, Mrs. Sebastiano (Argenia Genovesi) NaN  24.0   NaN
# van Billiard, Master. Walter John             NaN   NaN  11.5
#
# [332 rows x 3 columns]

# %%
import numpy as np
Titanic_array = np.array(["Name","Age"])

print(Titanic_array.shape)
# Out:
# (2,)

# %%
Titanic.size# multiplying the number of rows by the number of columns.
# Out:
# 5016

# %%
Titanic.axes[0]
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
Titanic.axes[1]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
Titanic.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
np.mean(Titanic["Age"].dropna())  # Result is calculated but not stored
# Out:
# 30.272590361445783

# %%
np.max(Titanic["Fare"].dropna())
# Out:
# 512.3292

# %%
np.array(Titanic["Pclass"])  # Semicolon suppresses output
# Out:
# array([3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 2, 2, 3, 3, 3, 1, 3,
#        1, 1, 1, 3, 1, 3, 1, 3, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 1, 3, 2,
#        1, 3, 1, 3, 1, 3, 1, 2, 2, 1, 2, 3, 3, 3, 3, 1, 3, 2, 3, 3, 1, 2,
#        3, 1, 1, 1, 3, 3, 3, 1, 1, 1, 3, 1, 2, 3, 3, 1, 1, 3, 2, 3, 3, 3,
#        3, 2, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 3, 3, 2,
#        2, 3, 1, 3, 1, 3, 3, 3, 1, 2, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 1,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 3, 1, 3, 1, 2, 1, 3, 3, 3,
#        3, 3, 1, 3, 1, 3, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 3, 3, 3, 3, 2,
#        2, 1, 2, 1, 2, 1, 1, 3, 1, 2, 2, 3, 3, 2, 2, 1, 3, 2, 2, 3, 1, 3,
#        2, 3, 3, 3, 1, 2, 2, 1, 3, 2, 1, 3, 3, 3, 2, 2, 3, 1, 3, 1, 1, 3,
#        2, 3, 2, 3, 1, 3, 3, 3, 3, 2, 2, 1, 3, 3, 1, 3, 1, 3, 2, 1, 1, 2,
#        1, 3, 3, 1, 2, 2, 2, 3, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 1, 3, 3, 3, 1, 3, 1, 3, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3,
# ...

# %%
np.array(Titanic["Pclass"]).reshape((-1, 1))
# Out:
# array([[3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [2],
#        [2],
#        [3],
#        [3],
#        [1],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [3],
#        [3],
#        [1],
#        [2],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
# ...

# %%
np.std(Titanic["Fare"].dropna())
# Out:
# 55.84050047954103

# %%
np.where(Titanic["Age"].dropna() > 30)
# Out:
# (array([  0,   1,   2,  10,  12,  13,  15,  18,  19,  22,  23,  26,  27,
#          29,  34,  35,  37,  39,  40,  41,  47,  49,  51,  56,  57,  58,
#          63,  64,  65,  69,  70,  78,  81,  82,  89,  90,  92,  95,  98,
#         102, 104, 105, 106, 111, 113, 114, 116, 117, 121, 122, 127, 131,
#         133, 138, 141, 142, 143, 145, 148, 151, 152, 154, 156, 161, 164,
#         166, 168, 170, 171, 172, 173, 174, 179, 181, 182, 186, 188, 191,
#         192, 193, 194, 195, 197, 203, 207, 213, 217, 224, 227, 228, 233,
#         234, 236, 239, 240, 243, 244, 246, 253, 254, 257, 260, 261, 265,
#         266, 269, 270, 273, 275, 276, 279, 281, 282, 286, 290, 293, 294,
#         295, 296, 297, 300, 306, 310, 312, 316, 318, 320, 323, 326, 328,
#         330, 331]),)

# %%
np.sum(Titanic["SibSp"])
# Out:
# 187

# %%
np.min(Titanic["Parch"])
# Out:
# 0

# %%
np.unique(Titanic["Pclass"], return_counts=True)
# Out:
# (array([1, 2, 3]), array([107,  93, 218]))

# %%
np.nanmedian(Titanic["Age"])
# Out:
# 27.0

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
np.percentile(Titanic["Fare"].dropna(), 75)
# Out:
# 31.5

# %%
np.any(Titanic["Pclass"] > 2)
# Out:
# True

# %%
np.percentile(Titanic["Fare"].dropna(), 75)
# Out:
# 31.5

# %%
np.cumsum(Titanic["SibSp"])
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        2
#       ...
# 413    186
# 414    186
# 415    186
# 416    186
# 417    187
# Name: SibSp, Length: 418, dtype: int64

# %%
np.unique(Titanic["Embarked"].dropna(), return_counts=True)
# Out:
# (array(['C', 'Q', 'S'], dtype=object), array([102,  46, 270]))

# %%
age_fare = Titanic[["Age", "Fare"]].dropna()
   np.dot(age_fare["Age"], age_fare["Fare"])

# %%
np.dot(Titanic[["Age", "Fare"]].dropna()["Age"], Titanic[["Age", "Fare"]].dropna()["Fare"])
# Out:
# 505717.79355

# %%
np.random.choice(Titanic.index, size=5, replace=False)
# Out:
# array([239, 283, 148,   3, 189])

# %%
Titanic["Fare"].values.sort() # Modifies the DataFrame directly

# %%
np.var(Titanic["Age"].dropna())
# Out:
# 200.50095232617215

# %%
Titanic['Fare'].median()
# Out:
# 14.4542

# %%
Titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
Titanic.sample()
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 150         1042         1       1  Earnshaw, Mrs. Boulton (Olive Potter)
#
#         Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 150  female  23.0      0      1  11767  9.35   C54        C

# %%
Titanic['Embarked'].mode()[0]
# Out:
# 'S'

# %%
Titanic['Fare'].idxmax()
# Out:
# 416

# %%
Titanic.query('Age > 30 and Pclass == 1')
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 14           906         1       1
# 20           912         0       1
# 24           916         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 397         1289         1       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic.stack()
# Out:
# 0    PassengerId                 892
#      Survived                      0
#      Pclass                        3
#      Name           Kelly, Mr. James
#      Sex                        male
#                           ...
# 417  Sex                        male
#      SibSp                         1
#      Parch                         1
#      Ticket                     2668
#      Embarked                      C
# Length: 4602, dtype: object

# %%
Titanic.unstack()
# Out:
# PassengerId  0      892
#              1      893
#              2      894
#              3      895
#              4      896
#                    ...
# Embarked     413      S
#              414      C
#              415      S
#              416      S
#              417      C
# Length: 5016, dtype: object

# %%
Titanic.explode('Cabin')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
Titanic.melt(id_vars=['PassengerId'], value_vars=['Age', 'Fare'])
# Out:
#      PassengerId variable     value
# 0            892      Age   34.5000
# 1            893      Age   47.0000
# 2            894      Age   62.0000
# 3            895      Age   27.0000
# 4            896      Age   22.0000
# ..           ...      ...       ...
# 831         1305     Fare  262.3750
# 832         1306     Fare  263.0000
# 833         1307     Fare  263.0000
# 834         1308     Fare  512.3292
# 835         1309     Fare       NaN
#
# [836 rows x 3 columns]

# %%
Titanic.agg({'Age': ['mean', 'std'], 'Fare': 'max'})
# Out:
#             Age      Fare
# mean  30.272590       NaN
# std   14.181209       NaN
# max         NaN  512.3292

# %%
Titanic.rolling(window=3)['Age'].mean()#Rolling average of age over a window of 3.
# Out:
# 0            NaN
# 1            NaN
# 2      47.833333
# 3      45.333333
# 4      37.000000
#          ...
# 413          NaN
# 414          NaN
# 415          NaN
# 416          NaN
# 417          NaN
# Name: Age, Length: 418, dtype: float64

# %%
Titanic['Name'].str.upper()
# Out:
# 0                                  KELLY, MR. JAMES
# 1                  WILKES, MRS. JAMES (ELLEN NEEDS)
# 2                         MYLES, MR. THOMAS FRANCIS
# 3                                  WIRZ, MR. ALBERT
# 4      HIRVONEN, MRS. ALEXANDER (HELGA E LINDQVIST)
#                            ...
# 413                              SPECTOR, MR. WOOLF
# 414                    OLIVA Y OCANA, DONA. FERMINA
# 415                    SAETHER, MR. SIMON SIVERTSEN
# 416                             WARE, MR. FREDERICK
# 417                        PETER, MASTER. MICHAEL J
# Name: Name, Length: 418, dtype: object

# %%
Titanic['Name'].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
Titanic['Name'].str.contains('Mr')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417    False
# Name: Name, Length: 418, dtype: bool

# %%
Titanic['Name'].str.split(',')[0]
# Out:
# ['Kelly', ' Mr. James']

# %%
Titanic['Cabin'].str.extract('(\d+)')
# Out:
#        0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 413  NaN
# 414  105
# 415  NaN
# 416  NaN
# 417  NaN
#
# [418 rows x 1 columns]

# %%
Titanic['Name'].str.replace('Mrs', 'Ms')
# Out:
# 0                                 Kelly, Mr. James
# 1                  Wilkes, Ms. James (Ellen Needs)
# 2                        Myles, Mr. Thomas Francis
# 3                                 Wirz, Mr. Albert
# 4      Hirvonen, Ms. Alexander (Helga E Lindqvist)
#                           ...
# 413                             Spector, Mr. Woolf
# 414                   Oliva y Ocana, Dona. Fermina
# 415                   Saether, Mr. Simon Sivertsen
# 416                            Ware, Mr. Frederick
# 417                       Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
Titanic.expanding()
# Out:
# Expanding [min_periods=1,axis=0,method=single]

# %%
Titanic.hist()
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
Titanic.round(decimals=2)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
Titanic.loc[Titanic['Age'] > 30, 'Name']
# Out:
# 0                                     Kelly, Mr. James
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 2                            Myles, Mr. Thomas Francis
# 11                          Jones, Mr. Charles Cresson
# 13                                Howard, Mr. Benjamin
#                             ...
# 404                       Frauenthal, Mr. Isaac Gerald
# 407                         Widener, Mr. George Dunton
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414                       Oliva y Ocana, Dona. Fermina
# 415                       Saether, Mr. Simon Sivertsen
# Name: Name, Length: 132, dtype: object

# %%
Titanic.mask(Titanic['Age'] > 30, 'Name')
# Out:
#     PassengerId Survived Pclass                                          Name  \
# 0          Name     Name   Name                                          Name
# 1          Name     Name   Name                                          Name
# 2          Name     Name   Name                                          Name
# 3           895        0      3                              Wirz, Mr. Albert
# 4           896        1      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..          ...      ...    ...                                           ...
# 413        1305        0      3                            Spector, Mr. Woolf
# 414        Name     Name   Name                                          Name
# 415        Name     Name   Name                                          Name
# 416        1308        0      3                           Ware, Mr. Frederick
# 417        1309        0      3                      Peter, Master. Michael J
#
# ...

# %%
Titanic.where(Titanic['Age'] > 30, 'Name')
# Out:
#     PassengerId Survived Pclass                              Name     Sex  \
# 0           892        0      3                  Kelly, Mr. James    male
# 1           893        1      3  Wilkes, Mrs. James (Ellen Needs)  female
# 2           894        0      2         Myles, Mr. Thomas Francis    male
# 3          Name     Name   Name                              Name    Name
# 4          Name     Name   Name                              Name    Name
# ..          ...      ...    ...                               ...     ...
# 413        Name     Name   Name                              Name    Name
# 414        1306        1      1      Oliva y Ocana, Dona. Fermina  female
# 415        1307        0      3      Saether, Mr. Simon Sivertsen    male
# 416        Name     Name   Name                              Name    Name
# 417        Name     Name   Name                              Name    Name
#
#       Age SibSp Parch              Ticket    Fare Cabin Embarked
# ...

# %%
Titanic.drop_duplicates(subset=['Age'])
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 373         1265         0       2
# 379         1271         0       3
# 391         1283         1       1
# 409         1301         1       3
# 415         1307         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 0                                  Kelly, Mr. James    male  34.5      0
# 1                  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                         Myles, Mr. Thomas Francis    male  62.0      0
# 3                                  Wirz, Mr. Albert    male  27.0      0
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                              ...     ...   ...    ...
# ...

# %%
Titanic.plot(x='Age', y='Fare', kind='scatter')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
Titanic.sort_values(by=['Age', 'Fare'], ascending=[True, False])
# Out:
#      PassengerId  Survived  Pclass  \
# 354         1246         1       3
# 201         1093         0       3
# 281         1173         0       3
# 307         1199         0       3
# 250         1142         1       2
# ..           ...       ...     ...
# 29           921         0       3
# 33           925         1       3
# 22           914         1       1
# 10           902         0       3
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 354            Dean, Miss. Elizabeth Gladys Millvina""  female  0.17      1
# 201            Danbom, Master. Gilbert Sigvard Emanuel    male  0.33      0
# 281                     Peacock, Master. Alfred Edward    male  0.75      1
# 307                          Aks, Master. Philip Frank    male  0.83      0
# 250                              West, Miss. Barbara J  female  0.92      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic.values
# Out:
# array([[892, 0, 3, ..., 0.0, nan, 'Q'],
#        [893, 1, 3, ..., 0.0, nan, 'S'],
#        [894, 0, 2, ..., 3.1708, nan, 'Q'],
#        ...,
#        [1307, 0, 3, ..., 263.0, nan, 'S'],
#        [1308, 0, 3, ..., 512.3292, nan, 'S'],
#        [1309, 0, 3, ..., nan, nan, 'C']], dtype=object)

# %%
Titanic.plot.area()
# Out:
# <Axes: >

# %%
Titanic.plot.bar()
# Out:
# <Axes: >

# %%
Titanic.boxplot()
# Out:
# <Axes: >
