# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi2469/Python-Training/blob/main/Day-5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('/content/Customer_Choice_Survey.csv')

# %%
x
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"Europe/Ber...
# 2                                  2019-03-27 12:38:03
# 3                                  2019-03-27 12:54:16
# 4                                  2019-03-27 13:02:43
# ..                                                 ...
# 136                                2019-03-29 14:55:00
# 137                                2019-03-29 14:48:14
# 138                                2019-03-29 15:05:25
# 139                                2019-03-29 15:08:11
# 140                                2019-03-29 15:50:52
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"Europe/Berlin"}  {"ImportId":"status"}
# ...

# %%
x.isnull().sum()
# Out:
# StartDate     0
# EndDate       0
# Status        0
# IPAddress     0
# Progress      0
#              ..
# Q22           0
# Q23           0
# Q25           0
# Q88           0
# Q89          19
# Length: 69, dtype: int64

# %%
missing_values=['N/a','na',np.nan]
x=pd.read_csv('/content/Customer_Choice_Survey.csv',na_values=missing_values)

# %%
df.isnull()
# Out:
#      StartDate  EndDate  Status  IPAddress  Progress  Duration (in seconds)  \
# 0        False    False   False      False     False                  False
# 1        False    False   False      False     False                  False
# 2        False    False   False      False     False                  False
# 3        False    False   False      False     False                  False
# 4        False    False   False      False     False                  False
# ..         ...      ...     ...        ...       ...                    ...
# 136      False    False   False      False     False                  False
# 137      False    False   False      False     False                  False
# 138      False    False   False      False     False                  False
# 139      False    False   False      False     False                  False
# 140      False    False   False      False     False                  False
#
# ...

# %%
df.isnull().sum()
# Out:
# StartDate     0
# EndDate       0
# Status        0
# IPAddress     0
# Progress      0
#              ..
# Q22           0
# Q23           0
# Q25           0
# Q88           0
# Q89          19
# Length: 69, dtype: int64

# %%
df.isnull().any()
# Out:
# StartDate    False
# EndDate      False
# Status       False
# IPAddress    False
# Progress     False
#              ...
# Q22          False
# Q23          False
# Q25          False
# Q88          False
# Q89           True
# Length: 69, dtype: bool

# %%
x.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
 x.fillna(x.mean(numeric_only=True))
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"Europe/Ber...
# 2                                  2019-03-27 12:38:03
# 3                                  2019-03-27 12:54:16
# 4                                  2019-03-27 13:02:43
# ..                                                 ...
# 136                                2019-03-29 14:55:00
# 137                                2019-03-29 14:48:14
# 138                                2019-03-29 15:05:25
# 139                                2019-03-29 15:08:11
# 140                                2019-03-29 15:50:52
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"Europe/Berlin"}  {"ImportId":"status"}
# ...

# %%
x.mode()
# Out:
#                                              StartDate              EndDate  \
# 0                                  2019-03-27 12:38:03  2019-03-29 11:19:56
# 1                                  2019-03-27 12:54:16                  NaN
# 2                                  2019-03-27 13:02:43                  NaN
# 3                                  2019-03-27 13:20:02                  NaN
# 4                                  2019-03-27 14:49:49                  NaN
# ..                                                 ...                  ...
# 136                                2019-03-29 15:05:25                  NaN
# 137                                2019-03-29 15:08:11                  NaN
# 138                                2019-03-29 15:50:52                  NaN
# 139                                         Start Date                  NaN
# 140  {"ImportId":"startDate","timeZone":"Europe/Ber...                  NaN
#
# ...

# %%
 x.fillna(x.mode())
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"Europe/Ber...
# 2                                  2019-03-27 12:38:03
# 3                                  2019-03-27 12:54:16
# 4                                  2019-03-27 13:02:43
# ..                                                 ...
# 136                                2019-03-29 14:55:00
# 137                                2019-03-29 14:48:14
# 138                                2019-03-29 15:05:25
# 139                                2019-03-29 15:08:11
# 140                                2019-03-29 15:50:52
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"Europe/Berlin"}  {"ImportId":"status"}
# ...

# %%
x.select_dtypes(include=['float64']).median()
# Out:
# Series([], dtype: float64)

# %%
x.median(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
 x.fillna(x.median(numeric_only=True))
# Out:
#                                              StartDate  \
# 0                                           Start Date
# 1    {"ImportId":"startDate","timeZone":"Europe/Ber...
# 2                                  2019-03-27 12:38:03
# 3                                  2019-03-27 12:54:16
# 4                                  2019-03-27 13:02:43
# ..                                                 ...
# 136                                2019-03-29 14:55:00
# 137                                2019-03-29 14:48:14
# 138                                2019-03-29 15:05:25
# 139                                2019-03-29 15:08:11
# 140                                2019-03-29 15:50:52
#
#                                                EndDate                 Status  \
# 0                                             End Date          Response Type
# 1    {"ImportId":"endDate","timeZone":"Europe/Berlin"}  {"ImportId":"status"}
# ...

# %%
x.describe()
# Out:
#          StartDate              EndDate      Status     IPAddress Progress  \
# count          141                  141         141           141      141
# unique         141                  140           3           138        3
# top     Start Date  2019-03-29 11:19:56  IP Address  24.171.75.95      100
# freq             1                    2         139             2      139
#
#        Duration (in seconds) Finished   RecordedDate   ResponseId  \
# count                    141      141            141          141
# unique                   135        3            141          141
# top                      370     True  Recorded Date  Response ID
# freq                       2      139              1            1
#
#           RecipientLastName  ...              Q17  \
# count                     2  ...              141
# unique                    2  ...                9
# top     Recipient Last Name  ...  35-44 years old
# freq                      1  ...               52
#
# ...

# %%
import seaborn as sns
sns.displot(x['Q25'])

# %%
sns.boxplot(x['Q20'])
# Out:
# <Axes: ylabel='Q20'>
