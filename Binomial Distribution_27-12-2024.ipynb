# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi2469/Python-Training/blob/main/Day-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv('/content/Customer_Choice_Survey.csv')

# %%
import matplotlib.pyplot as plt

sns.lineplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='ResponseId', ylabel='Q19'>

# %%
plt.plot(x_values, y_values)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Sine Wave')
plt.show()

# %%
plt.scatter(x_values, y_values)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %%
import seaborn as sns

# %%
sns.lineplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='ResponseId', ylabel='Q19'>

# %%
sns.scatterplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='ResponseId', ylabel='Q19'>

# %%
sns.barplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='ResponseId', ylabel='Q19'>

# %%
sns.histplot(x=y_values)  # Histogram of Q19 values
# Out:
# <Axes: xlabel='Q19', ylabel='Count'>

# %%
import scipy.stats as stats
# Number of trials
n = 10

# Probability of success
p = 0.5

# Calculate x-axis values (number of successes from 0 to n)
x_values = np.arange(0, n + 1)

# Calculate PMF directly using binom.pmf
y_values = stats.binom.pmf(x_values, n, p)

# Create the plot
plt.bar(x_values, y_values)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF')
plt.show()

# %%
import seaborn as sns

import pandas as pd

import numpy as np



# Sample DataFrame

df = pd.DataFrame(np.random.randn(10, 5), columns=['A', 'B', 'C', 'D', 'E'])



corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix')

plt.show()
