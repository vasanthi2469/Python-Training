# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthi2469/Python-Training/blob/main/MiniProject_05-12-2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Ignore warnings to suppress potential warnings during execution.
# warnings.filterwarnings('ignore')

# %%
#task 1-READING THE DATASET
Set=pd.read_csv('/content/dataset.csv')

# %% [markdown]
# ## **Task 1**: Reading the dataset
# # This line uses the pandas library to read a CSV file named 'dataset.csv' located in the '/content/' directory.
# # The contents of the CSV file are loaded into a pandas DataFrame called 'Set'.
# # A DataFrame is a two-dimensional labeled data structure with columns of potentially different types.
# Set = pd.read_csv('/content/dataset.csv')

# %%
# prompt: i need explination for above code

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
Set
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
#Task2 -CHECKING MISSING VALUES & IF THERE ARE SOME DUBLICATE ROWS OR NOT



# prompt: Using dataframe Set: CHECKING MISSING VALUES & IF THERE ARE SOME DUBLICATE ROWS OR NOT

# Check for missing values
print(Set.isnull().sum())

# Check for duplicate rows
print(Set.duplicated().sum())
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64
# 0

# %% [markdown]
# # **TASK-2**
# Checking for Missing Values and Duplicates:**
#
# - `print(Set.isnull().sum())`: This line checks for missing values (NaN - Not a Number) in each column of the DataFrame. `Set.isnull()` creates a DataFrame of boolean values (True if a value is missing, False otherwise).  `.sum()` then counts the number of `True` values in each column, effectively giving the number of missing values per column. The result is printed to the console.
#
# - `print(Set.duplicated().sum())`: This line checks for duplicate rows in the entire DataFrame.  `Set.duplicated()` returns a Series of boolean values, indicating whether each row is a duplicate of a preceding row. `.sum()` then counts the total number of duplicate rows, and the result is printed.
#
# In summary, the code reads a CSV file into a pandas DataFrame, displays the data, and checks for missing values and duplicate rows—a crucial first step in most data analysis workflows.  However, since the code doesn't define any further processing steps, the missing values and duplicates aren't handled. Further code would be needed to clean and prepare the data for modeling or visualization.

# %%
#Task-3 PLOTTING THE DISTRIBUTION OF VARIOUS DISCRETE FEATURES ON SEASON/HOLIDAY/WEEKEND/WEATHERCODE
# prompt: Using dataframe Set: PLOTTING THE DISTRIBUTION OF VARIOUS DISCRETE FEATURES ON SEASON/HOLIDAY/WEEKEND/WEATHERCODE

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert 'timestamp' to datetime objects if not already
Set['timestamp'] = pd.to_datetime(Set['timestamp'])

# Create discrete features for plotting
discrete_features = ['season', 'is_holiday', 'is_weekend', 'weather_code']

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create subplots for each discrete feature
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

# Iterate over discrete features and create distributions
for i, feature in enumerate(discrete_features):
    sns.countplot(x=feature, data=Set, ax=axes[i])
    axes[i].set_title(f"Distribution of {feature}")
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Task 3**: Plotting the distribution of various discrete features
#
# # Convert the 'timestamp' column to datetime objects.  This is important for time-series analysis.
# Set['timestamp'] = pd.to_datetime(Set['timestamp'])
#
# # Define a list of discrete features (categorical variables) to analyze
# discrete_features = ['season', 'is_holiday', 'is_weekend', 'weather_code']
#
# # Set the plotting style using seaborn's 'whitegrid' style, which provides a clean background.
# sns.set_style("whitegrid")
#
# # Create a figure and a set of subplots (2x2 grid) for visualizing the distributions.
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# axes = axes.flatten() # Flatten the axes array for easier iteration
#
#
# # Loop through each discrete feature and create a countplot to show its distribution.
# for i, feature in enumerate(discrete_features):
#     sns.countplot(x=feature, data=Set, ax=axes[i])  # Create a countplot for the current feature.
#     axes[i].set_title(f"Distribution of {feature}")  # Set the title of the subplot.
#     axes[i].set_xlabel(feature)  # Set the x-axis label.
#     axes[i].set_ylabel("Count")  # Set the y-axis label.
#
#
# plt.tight_layout()  # Adjusts subplot parameters for a tight layout
# plt.show()  # Display the plots

# %%
Set.isnull().sum()
Set.duplicated().sum()
# Out:
# 0

# %%
#TASK 04 - LOOKING AT THE DATA TYPES OF EACH VARIABLE, TRANSFORM TIMESTAMP IN TYPE & SET IT AS INDEX
# prompt: Using dataframe Set: LOOKING AT THE DATA TYPES OF EACH VARIABLE, TRANSFORM TIMESTAMP IN TYPE & SET IT AS INDEX

# Check if 'timestamp' is already the index
if 'timestamp' not in Set.columns:
    # If 'timestamp' is not a column, it's likely the index
    # Reset the index to make 'timestamp' a column again
    Set = Set.reset_index()

# Convert 'timestamp' column to datetime objects
Set['timestamp'] = pd.to_datetime(Set['timestamp'])

# Set the 'timestamp' column as the index of the DataFrame
Set = Set.set_index('timestamp')
print(Set)
# Out:
#                      index   cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00      0   182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00      1   138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00      2   134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00      3    72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00      4    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 2017-01-03 19:00:00  17409  1042  5.0  1.0   81.0        19.0           3.0
# 2017-01-03 20:00:00  17410   541  5.0  1.0   81.0        21.0           4.0
# 2017-01-03 21:00:00  17411   337  5.5  1.5   78.5        24.0           4.0
# 2017-01-03 22:00:00  17412   224  5.5  1.5   76.0        23.0           4.0
# 2017-01-03 23:00:00  17413   139  5.0  1.0   76.0        22.0           2.0
#
# ...

# %% [markdown]
# # **TASK-4**. Data Type Check and Timestamp as Index:**
# *italicized text*
# - **Index Check:** The code first verifies if 'timestamp' is already the DataFrame's index using `if 'timestamp' not in Set.columns:`.  If 'timestamp' *is not* a column, it implies it's the index. In this case, `Set.reset_index()` converts the index into a column named 'timestamp'.
# - **Timestamp Conversion:** The code then converts the 'timestamp' column (whether originally a column or an index reset to a column) to datetime objects using `pd.to_datetime()`.
# - **Index Setting:**  `Set = Set.set_index('timestamp')` sets the 'timestamp' column as the index of the DataFrame.  This is common for time series data, facilitating time-based indexing and operations.  Finally `print(Set)` prints the modified DataFrame.
#
# **In summary:** The code reads a CSV, explores it for missing data and duplicates, visually inspects the distribution of specific categorical features, and prepares the dataset for further analysis by setting the 'timestamp' column as the index after ensuring it's in the correct datetime format.

# %%
#TASK 05 - MAKING FEATURE ENGINEERING. EXTRACTING NEW COLUMNS (DAY OF WEEK, DAY OF MONTH, HOUR, MONTH, SEASON, YEAR ETC.
import pandas as pd

# Assuming 'Set' is your DataFrame and 'timestamp' is the index
# Extract the features from the index
Set['year'] = Set.index.year
Set['month'] = Set.index.month
Set['day'] = Set.index.day
Set['hour'] = Set.index.hour
Set['dayofweek'] = Set.index.dayofweek


# Define a function to map month to season
def month_to_season(month):
    if 3 <= month <= 5:
        return 0  # Spring
    elif 6 <= month <= 8:
        return 1  # Summer
    elif 9 <= month <= 11:
        return 2  # Autumn
    else:
        return 3  # Winter

# Create the 'season' column based on month
Set['season_from_month'] = Set['month'].apply(month_to_season)

# Optionally, verify the new columns are included
Set.columns
Set.head()
# Out:
#                                index           timestamp  cnt   t1   t2  \
# 1970-01-01 00:00:00.000000000      0 2015-01-04 00:00:00  182  3.0  2.0
# 1970-01-01 00:00:00.000000001      1 2015-01-04 01:00:00  138  3.0  2.5
# 1970-01-01 00:00:00.000000002      2 2015-01-04 02:00:00  134  2.5  2.5
# 1970-01-01 00:00:00.000000003      3 2015-01-04 03:00:00   72  2.0  2.0
# 1970-01-01 00:00:00.000000004      4 2015-01-04 04:00:00   47  2.0  0.0
#
#                                  hum  wind_speed  weather_code  is_holiday  \
# 1970-01-01 00:00:00.000000000   93.0         6.0           3.0         0.0
# 1970-01-01 00:00:00.000000001   93.0         5.0           1.0         0.0
# 1970-01-01 00:00:00.000000002   96.5         0.0           1.0         0.0
# 1970-01-01 00:00:00.000000003  100.0         0.0           1.0         0.0
# 1970-01-01 00:00:00.000000004   93.0         6.5           1.0         0.0
#
#                                is_weekend  season  year  month  day  hour  \
# ...

# %% [markdown]
# # **TASK 05** - MAKING FEATURE ENGINEERING. EXTRACTING NEW COLUMNS (DAY OF WEEK, DAY OF MONTH, HOUR, MONTH, SEASON, YEAR ETC.
#  import pandas as pd
# # # Assuming 'Set' is your DataFrame and 'timestamp' is the index
# # # Extract the features from the index
# # Set['year'] = Set.index.year
# # Set['month'] = Set.index.month
# # Set['day'] = Set.index.day
# # Set['hour'] = Set.index.hour
# # Set['dayofweek'] = Set.index.dayofweek
# # # Define a function to map month to season
# # def month_to_season(month):
# #     if 3 <= month <= 5:
# #         return 0  # Spring
# #     elif 6 <= month <= 8:
# #         return 1  # Summer
# #     elif 9 <= month <= 11:
# #         return 2  # Autumn
# #     else:
# #         return 3  # Winter
# # # Create the 'season' column based on month
# # Set['season_from_month'] = Set['month'].apply(month_to_season)
# # # Optionally, verify the new columns are included
# # Set.columns
# # Set.head()(explination for this code)
#
# # The provided code is already well-commented.  Here's a slightly more detailed explanation:
#
# # TASK 05 - Feature Engineering: Extracting New Columns
#
# # Assuming 'Set' is your DataFrame and 'timestamp' is the index (which was set in Task 04)
#
# # Extract features from the DateTimeIndex:
# # - Set['year'] = Set.index.year: Extracts the year from the 'timestamp' index and creates a new 'year' column.
# # - Similar operations are performed for 'month', 'day', 'hour', and 'dayofweek'.
#
# # Define a function to map month to season:
# # The `month_to_season` function maps numerical month values to corresponding seasons (0: Spring, 1: Summer, 2: Autumn, 3: Winter).
#
# # Create the 'season_from_month' column:
# # - Set['season_from_month'] = Set['month'].apply(month_to_season): Applies the `month_to_season` function to each value in the 'month' column, creating a new 'season_from_month' column based on the season mapping.
#
#
# # Verification:
# # - Set.columns: Displays the column names in the DataFrame to confirm the new columns have been added.
# # - Set.head(): Shows the first few rows of the modified DataFrame to visually inspect the newly created columns and their values.

# %%
#TASK 06 - VISUALIZING THE CORRELATION WITH A HEATMAP
# prompt: Using dataframe Set: VISUALIZING THE CORRELATION WITH A HEATMAP

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
corr_matrix = Set.corr()

# Create a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ## #***TASK 06  ***- VISUALIZING THE CORRELATION WITH A HEATMAP
# # # prompt: Using dataframe Set: VISUALIZING THE CORRELATION WITH A HEATMAP
# # import matplotlib.pyplot as plt
# # import seaborn as sns
# # # Calculate the correlation matrix
# # corr_matrix = Set.corr()
# # # Create a heatmap
# # plt.figure(figsize=(12, 10))
# # sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# # plt.title('Correlation Matrix Heatmap')
# # plt.show()
# # (i need explination for this code)
#
# #TASK 06 - VISUALIZING THE CORRELATION WITH A HEATMAP
# # This code visualizes the correlation between different features (columns) in the 'Set' DataFrame using a heatmap.
#
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Calculate the correlation matrix
# # The .corr() method calculates the pairwise correlation of columns, excluding NA/null values.
# # The result is a DataFrame where each cell represents the correlation between two columns.
# corr_matrix = Set.corr()
#
# # Create a heatmap
# # plt.figure(figsize=(12, 10)): Creates a new figure for the plot with a specified size (12 inches wide, 10 inches high).
# # sns.heatmap(...): Generates the heatmap.
# #     corr_matrix: The correlation matrix to visualize.
# #     annot=True: Displays the correlation values on the heatmap itself.
# #     cmap='coolwarm': Sets the color map for the heatmap, using a 'coolwarm' scheme (blue for negative correlations, red for positive correlations).
# #     fmt=".2f": Formats the correlation values displayed on the heatmap to two decimal places.
# plt.figure(figsize=(12, 10))
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# plt.title('Correlation Matrix Heatmap') # Sets the title of the heatmap plot.
# plt.show() # Displays the heatmap.

# %%
#TASK 07 - VISUALIZING THE CORRELATION OF THE TARGET VARIABLE & THE OTHER FEATURES WITH BARPLO
# prompt: Using dataframe Set: VISUALIZING THE CORRELATION OF THE TARGET VARIABLE & THE OTHER FEATURES WITH BARPLOT

import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the correlation matrix
corr_matrix = Set.corr()

# Extract the correlations with the 'cnt' column (target variable)
correlations = corr_matrix['cnt'].drop('cnt')  # Exclude the self-correlation

# Create the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=correlations.index, y=correlations.values)
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Features')
plt.ylabel('Correlation with cnt')
plt.title('Correlation of Features with Target Variable (cnt)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Task-7:-**This code visualizes the correlation between the target variable ('cnt') and other features in the 'Set' DataFrame using a bar plot.
#
# # Calculate the correlation matrix
# corr_matrix = Set.corr()
#
# # Extract correlations with 'cnt'
# # corr_matrix['cnt'] selects the column containing correlations of all other columns with 'cnt'.
# # .drop('cnt') removes the self-correlation of 'cnt' with itself (which is always 1).
# correlations = corr_matrix['cnt'].drop('cnt')
#
# # Create the bar plot
# plt.figure(figsize=(10, 6))  # Sets the figure size for better visualization.
# sns.barplot(x=correlations.index, y=correlations.values)  # Creates the barplot.
# # x-axis: Feature names (index of the 'correlations' Series).
# # y-axis: Correlation values (values of the 'correlations' Series).
#
# plt.xticks(rotation=90)  # Rotates x-axis labels to prevent overlapping.
# plt.xlabel('Features')  # Sets the x-axis label.
# plt.ylabel('Correlation with cnt')  # Sets the y-axis label.
# plt.title('Correlation of Features with Target Variable (cnt)')  # Sets the plot title.
# plt.tight_layout()  # Adjusts subplot parameters for a tight layout.
# plt.show()  # Displays the plot.

# %%
#TASK 08 - PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT
# prompt: Using dataframe Set: PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT

import plotly.express as px

# Reset index to convert 'timestamp' to a column
Set = Set.reset_index()  # This creates a 'timestamp' column

# Create the line plot
fig = px.line(Set, x="timestamp", y="cnt", title="Bike Shares Over Time")

# Display the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##***TASK 08*** - PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT
# # The code creates a line plot to visualize the bike shares ('cnt' column) over time ('timestamp' column) using the Plotly library.
#
# # Resetting the index:
# # Before plotting, the 'timestamp' column which was previously set as the index of the DataFrame is converted back to a regular column.
# # This is necessary because Plotly Express needs both the x and y values to be columns in the DataFrame.
# # `Set = Set.reset_index()` achieves this.
#
# # Creating the line plot:
# # `fig = px.line(Set, x="timestamp", y="cnt", title="Bike Shares Over Time")` creates the line plot using `plotly.express`.
# # - `Set`: The DataFrame containing the data.
# # - `x="timestamp"`: Specifies the 'timestamp' column as the x-axis (representing time).
# # - `y="cnt"`: Specifies the 'cnt' column as the y-axis (representing the number of bike shares).
# # - `title="Bike Shares Over Time"`: Sets the title of the plot.
#
# # Displaying the plot:
# # `fig.show()` displays the generated line plot. Plotly creates an interactive plot, allowing users to zoom, pan, and hover over data points to see details.

# %%
#TASK 09 - PLOTTING BIKE SHARES BY MONTHS & YEAR_OF_MONTH (USE LINEPLOT, POINTPOT, BARPLOT)
# prompt: Using dataframe Set:  PLOTTING BIKE SHARES BY MONTHS & YEAR_OF_MONTH (USE LINEPLOT, POINTPOT, BARPLOT)

import matplotlib.pyplot as plt
import seaborn as sns

# Group data by month and year
month_year_data = Set.groupby(['year', 'month'])['cnt'].sum().reset_index()

# Line Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=month_year_data, x='month', y='cnt', hue='year', marker='o')
plt.title('Bike Shares by Month and Year (Line Plot)')
plt.xlabel('Month')
plt.ylabel('Total Bike Shares')
plt.show()


# Point Plot
plt.figure(figsize=(10, 6))
sns.pointplot(data=month_year_data, x='month', y='cnt', hue='year')
plt.title('Bike Shares by Month and Year (Point Plot)')
plt.xlabel('Month')
plt.ylabel('Total Bike Shares')
plt.show()

# Bar Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=month_year_data, x='month', y='cnt', hue='year')
plt.title('Bike Shares by Month and Year (Bar Plot)')
plt.xlabel('Month')
plt.ylabel('Total Bike Shares')
plt.show()

# %% [markdown]
# # **TASK-9**
#
#  This code visualizes bike share trends by month and year using three different plot types: line plot, point plot, and bar plot.**
#
# # Group data by month and year
# # The code first groups the data in the 'Set' DataFrame by 'year' and 'month', then sums the 'cnt' (presumably the number of bike shares) for each group. Finally, it converts the result back into a DataFrame.
# month_year_data = Set.groupby(['year', 'month'])['cnt'].sum().reset_index()
#
# # Line Plot
# # Creates a line plot showing bike share trends over the months, with different lines for each year.
# plt.figure(figsize=(10, 6)) # sets the figure size
# sns.lineplot(data=month_year_data, x='month', y='cnt', hue='year', marker='o') #creates lineplot with markers
# plt.title('Bike Shares by Month and Year (Line Plot)') #sets title
# plt.xlabel('Month') #sets x label
# plt.ylabel('Total Bike Shares') #sets y label
# plt.show() #displays the plot
#
#
# # Point Plot
# # Creates a point plot showing the average bike share count for each month, with error bars indicating the variability.
# plt.figure(figsize=(10, 6))
# sns.pointplot(data=month_year_data, x='month', y='cnt', hue='year')
# plt.title('Bike Shares by Month and Year (Point Plot)')
# plt.xlabel('Month')
# plt.ylabel('Total Bike Shares')
# plt.show()
#
# # Bar Plot
# # Creates a bar plot showing the total bike shares for each month, with different bars for each year.
# plt.figure(figsize=(12, 6))
# sns.barplot(data=month_year_data, x='month', y='cnt', hue='year')
# plt.title('Bike Shares by Month and Year (Bar Plot)')
# plt.xlabel('Month')
# plt.ylabel('Total Bike Shares')
# plt.show()

# %%
#	TASK 10 - PLOTTING BIKE SHARES BY HOURS ON (HOLIDAYS, WEEKEND, SEASON)
# prompt: Using dataframe Set: PLOTTING BIKE SHARES BY HOURS ON (HOLIDAYS, WEEKEND, SEASON)

import matplotlib.pyplot as plt
import seaborn as sns

# Group data by hour, holiday, weekend, and season
grouped_data = Set.groupby(['hour', 'is_holiday', 'is_weekend', 'season'])['cnt'].mean().reset_index()

# Create the plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='cnt', hue='season', style='is_weekend', data=grouped_data[grouped_data['is_holiday'] == 0]) # Plot for non-holidays
plt.title('Average Bike Shares by Hour (Non-Holidays)')
plt.xlabel('Hour')
plt.ylabel('Average Bike Shares')
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x='hour', y='cnt', hue='season', style='is_weekend', data=grouped_data[grouped_data['is_holiday'] == 1]) # Plot for holidays
plt.title('Average Bike Shares by Hour (Holidays)')
plt.xlabel('Hour')
plt.ylabel('Average Bike Shares')
plt.show()

# %% [markdown]
# # **Task-10**
# # This code analyzes bike share data to visualize how rentals vary by hour, considering holidays, weekends, and seasons.
#
# # Group data:
# # The code first groups the data in the 'Set' DataFrame based on four categorical features: 'hour', 'is_holiday', 'is_weekend', and 'season'. For each combination of these categories, it calculates the mean of 'cnt'(number of bike shares).
# grouped_data = Set.groupby(['hour', 'is_holiday', 'is_weekend', 'season'])['cnt'].mean().reset_index()
#
# # Plotting for non-holidays:
# # It then creates a line plot using seaborn's lineplot function to visualize the average bike share count ('cnt') per hour ('hour').
# # - 'hue' argument: Different lines for each season.
# # - 'style' argument: Different line styles for weekends and weekdays.
# # - `data=grouped_data[grouped_data['is_holiday'] == 0]`: Filters the data to include only non-holiday days.
# plt.figure(figsize=(12, 6))
# sns.lineplot(x='hour', y='cnt', hue='season', style='is_weekend', data=grouped_data[grouped_data['is_holiday'] == 0])
# plt.title('Average Bike Shares by Hour (Non-Holidays)')
# plt.xlabel('Hour')
# plt.ylabel('Average Bike Shares')
# plt.show()
#
#
# # Plotting for holidays:
# # It does the same as above but filters the data to include only holidays (`grouped_data['is_holiday'] == 1`).
# plt.figure(figsize=(12, 6))
# sns.lineplot(x='hour', y='cnt', hue='season', style='is_weekend', data=grouped_data[grouped_data['is_holiday'] == 1])
# plt.title('Average Bike Shares by Hour (Holidays)')
# plt.xlabel('Hour')
# plt.ylabel('Average Bike Shares')
# plt.show()

# %%
#	TASK 11 - PLOTTING BIKE SHARES BY DAY OF WEEK
# prompt: Using dataframe Set: PLOTTING BIKE SHARES BY DAY OF WEEK

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by day of the week and calculate the mean bike share count
bike_shares_by_day = Set.groupby('dayofweek')['cnt'].mean()

# Create a bar plot to visualize bike shares by day of the week
plt.figure(figsize=(10, 6))
sns.barplot(x=bike_shares_by_day.index, y=bike_shares_by_day.values)

# Customize the plot
plt.xlabel('Day of the Week (0=Sunday, 6=Saturday)')
plt.ylabel('Mean Bike Shares')
plt.title('Bike Shares by Day of Week')

# Display the plot
plt.show()

# %% [markdown]
# # **TASK-11**
# # Import necessary libraries
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Assuming 'Set' DataFrame is already defined and contains 'dayofweek' and 'cnt' columns.
# # If not, you need to define or load the DataFrame first.
#
# # Group the data by day of the week and calculate the mean bike share count
# bike_shares_by_day = Set.groupby('dayofweek')['cnt'].mean()
#
# # Create a bar plot to visualize bike shares by day of the week
# plt.figure(figsize=(10, 6))  # Adjust figure size for better visualization
# sns.barplot(x=bike_shares_by_day.index, y=bike_shares_by_day.values)
#
# # Customize the plot
# plt.xlabel('Day of the Week (0=Sunday, 6=Saturday)')  # Set x-axis label with explanation of the encoding
# plt.ylabel('Mean Bike Shares')  # Set y-axis label
# plt.title('Bike Shares by Day of Week')  # Set plot title
#
#
# # Display the plot
# plt.show()

# %%
#TASK 12 - PLOTTING BIKE SHARES BY DAY OF MONTH
# prompt: Using dataframe Set: PLOTTING BIKE SHARES BY DAY OF MONTH

import pandas as pd
import matplotlib.pyplot as plt

# Group the data by day of the month and calculate the mean bike share count for each day
bike_share_by_day = Set.groupby('day')['cnt'].mean()

# Create the plot
plt.figure(figsize=(10, 6))  # Adjust figure size for better readability
plt.plot(bike_share_by_day.index, bike_share_by_day.values)
plt.xlabel('Day of Month')
plt.ylabel('Average Bike Shares')
plt.title('Average Bike Shares by Day of Month')
plt.grid(True)
plt.show()

# %% [markdown]
# # **TASK-12**
# # This code creates a line plot showing the average number of bike shares for each day of the month.
#
# # Group the data:
# # The `groupby('day')['cnt'].mean()` part groups the data in the 'Set' DataFrame by the 'day' column (which represents the day of the month).  For each day, it calculates the mean of the 'cnt' column (which represents the number of bike shares). The result is a pandas Series where the index is the day of the month and the values are the average bike share counts for that day.
#
# bike_share_by_day = Set.groupby('day')['cnt'].mean()
#
# # Create the plot:
# # The code then creates a line plot using Matplotlib.
# plt.figure(figsize=(10, 6))  # Adjust figure size for better readability (makes the plot larger and clearer).
# plt.plot(bike_share_by_day.index, bike_share_by_day.values) # Plots the data.  The x-axis is the day of the month (the index of the Series), and the y-axis is the average bike share count (the values of the Series).
# plt.xlabel('Day of Month') #Sets x-axis label
# plt.ylabel('Average Bike Shares') # Sets y-axis label
# plt.title('Average Bike Shares by Day of Month') # Sets the plot title
# plt.grid(True) # Adds a grid to the plot (makes it easier to read values).
# plt.show() # Displays the plot

# %%
#	TASK 13 - PLOTTING BIKE SHARES BY YEAR & PLOTTING BIKE SHARES ON HOLIDAYS BY SEASON
# prompt: Using dataframe Set: PLOTTING BIKE SHARES BY YEAR & PLOTTING BIKE SHARES ON HOLIDAYS BY SEASON

import altair as alt

# Plot bike shares by year
alt.Chart(Set).mark_line().encode(
    x='year:N',
    y='mean(cnt)'
).properties(
    title='Average Bike Shares per Year'
)

# Plot bike shares on holidays by season
alt.Chart(Set[Set['is_holiday'] == 1]).mark_bar().encode(
    x='season:N',
    y='mean(cnt)',
    color='season:N'
).properties(
    title='Average Bike Shares on Holidays by Season'
)
# Out:
# alt.Chart(...)

# %%
#	TASK 14 - VISUALIZING THE DISTRIBUTION OF BIKE SHARES BY WEEKDAY-WEEKEND WITH USING PIECHART & BARPLOT
# prompt: Using dataframe Set: VISUALIZING THE DISTRIBUTION OF BIKE SHARES BY WEEKDAY-WEEKEND WITH USING PIECHART & BARPLOT

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the total bike shares for weekdays and weekends
weekday_count = Set[Set['is_weekend'] == 0]['cnt'].sum()
weekend_count = Set[Set['is_weekend'] == 1]['cnt'].sum()

# Create a pie chart
labels = ['Weekdays', 'Weekends']
sizes = [weekday_count, weekend_count]
colors = ['skyblue', 'lightcoral']

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Bike Shares by Weekday/Weekend')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()


# Create a bar plot
plt.figure(figsize=(6, 4))
sns.barplot(x=labels, y=sizes, palette=colors)
plt.xlabel('Day Type')
plt.ylabel('Total Bike Shares')
plt.title('Distribution of Bike Shares by Weekday/Weekend')
plt.show()

# %%
#Task-15
# prompt: Using dataframe Set: PLOTTING THE DISTRIBUTION OF WEATHER CODE BY SEASON

import matplotlib.pyplot as plt
import seaborn as sns

# Create the plot
plt.figure(figsize=(10, 6))
sns.countplot(x='season', hue='weather_code', data=Set)
plt.title('Distribution of Weather Code by Season')
plt.xlabel('Season')
plt.ylabel('Count')
plt.show()
